# %%
#分支结构
#单分支结构if：
#多分支结构if：elif:elif:else:
a= 1
if a==2:
    print(q)
else:
    print(0)
# Out:
# 0

# %%
#and和or语句,not取反
a = 100
b = 90
print(a>110 and b>100)
print(a<110 or b>100)
not(a>110)
# Out:
# False
# True
# True

# %%
#while循环语句
a =0
while a<10:#当满足条件的时候
    a+=1
print(a)
# Out:
# 10

# %%
#打印乘法表
i = 1
while i<10:
    j=1
    while j<=i:
        print(f"{j}*{i}={i*j}", end="\t")
        j+=1
    print(end="\n")
    i+=1
# Out:
# 1*1=1
# 1*2=2	2*2=4
# 1*3=3	2*3=6	3*3=9
# 1*4=4	2*4=8	3*4=12	4*4=16
# 1*5=5	2*5=10	3*5=15	4*5=20	5*5=25
# 1*6=6	2*6=12	3*6=18	4*6=24	5*6=30	6*6=36
# 1*7=7	2*7=14	3*7=21	4*7=28	5*7=35	6*7=42	7*7=49
# 1*8=8	2*8=16	3*8=24	4*8=32	5*8=40	6*8=48	7*8=56	8*8=64
# 1*9=9	2*9=18	3*9=27	4*9=36	5*9=45	6*9=54	7*9=63	8*9=72	9*9=81

# %%
i=1
while i<6:
    j=1
    while j<=i:
        print ("*", end=" ")
        j+=1
    i+=1
    print()
    #多个相同的值输出是可以print("*"*i)
    #continue是结束下面的程序，break是跳出当前循环
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *

# %%
#for循环
for i in range (5):
    print (i,end =" ")
# Out:
# 0 1 2 3 4
